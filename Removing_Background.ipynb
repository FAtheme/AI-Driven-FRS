# %% [markdown]
# #Removing Background
# Written by Fatemeh Barati
#
# I got help from https://www.geeksforgeeks.org/how-to-remove-the-background-from-an-image-using-python/

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install rembg
from rembg import remove
from PIL import Image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.4 MB/s eta 0:00:00
# ...

# %%
input = Image.open('Tshirt.webp')
plt.imshow(input)

# %%
output = remove(input)
plt.imshow(output)

# %%
output.save('Tshirt2.webp')
